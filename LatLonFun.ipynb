# %%
#pip freeze

# %%
import geopandas as gpd
import pandas as pd
import shapely.wkt
import shapely.geometry

# %%
df= pd.read_csv("https://raw.githubusercontent.com/Imageomics/LatLonCover/main/someCoordinates.csv")
df.head()
# Out:
#   Image_Label                                         Image_Link  \
# 0          p1  https://inaturalist-open-data.s3.amazonaws.com...
# 1          p3  https://inaturalist-open-data.s3.amazonaws.com...
# 2         p10  https://inaturalist-open-data.s3.amazonaws.com...
# 3         p12  https://inaturalist-open-data.s3.amazonaws.com...
# 4         p13  https://inaturalist-open-data.s3.amazonaws.com...
#
#                Species        User     Date      Time  Seconds  \
# 0                  NaN  dan_equids   6/1/22   9:52:42    35562
# 1                  NaN  dan_equids  5/29/22  12:44:31    45871
# 2                  NaN  dan_equids   7/8/23  12:42:59    45779
# 3                  NaN  dan_equids   7/9/23  11:51:00    42660
# 4  bird's-foot trefoil  dan_equids   7/9/23  11:52:09    42729
#
#                                 Place        Lat        Lon  ...  Unnamed: 51  \
# 0        Carter Rd, Princeton, NJ, US  40.345062 -74.725237  ...          NaN
# ...

# %%
gdf= gpd.GeoDataFrame(df, geometry= geopandas.points_from_xy(df['Lon'], df['Lat']),crs=4326)
gdf.head()
# Out:
#   Image_Label                                         Image_Link  \
# 0          p1  https://inaturalist-open-data.s3.amazonaws.com...
# 1          p3  https://inaturalist-open-data.s3.amazonaws.com...
# 2         p10  https://inaturalist-open-data.s3.amazonaws.com...
# 3         p12  https://inaturalist-open-data.s3.amazonaws.com...
# 4         p13  https://inaturalist-open-data.s3.amazonaws.com...
#
#                Species        User     Date      Time  Seconds  \
# 0                  NaN  dan_equids   6/1/22   9:52:42    35562
# 1                  NaN  dan_equids  5/29/22  12:44:31    45871
# 2                  NaN  dan_equids   7/8/23  12:42:59    45779
# 3                  NaN  dan_equids   7/9/23  11:51:00    42660
# 4  bird's-foot trefoil  dan_equids   7/9/23  11:52:09    42729
#
#                                 Place        Lat        Lon  ...  Unnamed: 52  \
# 0        Carter Rd, Princeton, NJ, US  40.345062 -74.725237  ...          NaN
# ...

# %%
#convert geometry to albers
gdf['geometry_albers'] = gdf['geometry'].to_crs(epsg=5070)
gdf.head()
# Out:
#   Image_Label                                         Image_Link  \
# 0          p1  https://inaturalist-open-data.s3.amazonaws.com...
# 1          p3  https://inaturalist-open-data.s3.amazonaws.com...
# 2         p10  https://inaturalist-open-data.s3.amazonaws.com...
# 3         p12  https://inaturalist-open-data.s3.amazonaws.com...
# 4         p13  https://inaturalist-open-data.s3.amazonaws.com...
#
#                Species        User     Date      Time  Seconds  \
# 0                  NaN  dan_equids   6/1/22   9:52:42    35562
# 1                  NaN  dan_equids  5/29/22  12:44:31    45871
# 2                  NaN  dan_equids   7/8/23  12:42:59    45779
# 3                  NaN  dan_equids   7/9/23  11:51:00    42660
# 4  bird's-foot trefoil  dan_equids   7/9/23  11:52:09    42729
#
#                                 Place        Lat        Lon  ...  Unnamed: 53  \
# 0        Carter Rd, Princeton, NJ, US  40.345062 -74.725237  ...          NaN
# ...

# %%
#convert geometry to albers
gdf['geometry'].to_crs(epsg=5070)
                       
                       
from shapely.geometry import Point
d = {'col1': ['name1', 'name2'], 'geometry': [Point(1, 2), Point(2, 1)]}
gdf = geopandas.GeoDataFrame(d, crs=4326)
gdf
# Out:
#     col1                 geometry
# 0  name1  POINT (1.00000 2.00000)
# 1  name2  POINT (2.00000 1.00000)
